# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your data
data = {
    't': list(range(30)),
    'A0': [3.23088908, -0.15579908, 0.0253485498, 0.0345065295, 0.22087995, -0.27608535, -0.186049122, 0.150836621, 0.128753633, -0.192465138, 0.0493706386, -0.36935486, -0.0148848833, 0.40216813, 0.0279594128, 0.185707798, -0.304579833, 0.113087007, -0.290607242, 0.00582962321, 0.0453751285, -0.100075476, -0.413942610, -0.164332219, 0.0371404733, 0.0371404733, -0.0349718388, 0.0248869999, 0.472575770, 0.00986190153],
    'A1': [3.23292104, -0.15588155, 0.0252793811, 0.03451227, 0.22086494, -0.27612925, -0.185863348, 0.150900388, 0.128680194, -0.19243202, 0.049186364, -0.369041789, -0.0147604643, 0.402184181, 0.0280996736, 0.185745685, -0.304736916, 0.11302369, -0.290423752, 0.00596237028, 0.0453949983, -0.10004935, -0.413826876, -0.164485787, 0.0374024201, 0.0374024201, -0.0349312439, 0.0247754446, 0.472360295, 0.0100328755],
    'A2': [-0.29508634, 0.93833397, 0.893633804, 1.12065744, 1.24050653, 0.69139953, 1.24684475, 1.17270028, 0.918852435, 0.75589035, 1.4763445, 0.745782402, 0.747031156, 1.31373418, 1.15258322, 1.47387848, 1.12091179, 1.18565676, 0.52729697, 1.03324119, 0.725156065, 1.1207804, 0.915896718, 0.750973341, 1.00675611, 1.00675611, 1.18172641, 0.953284406, 0.817594128, 0.42872237],
    'A3': [-32.88669929, 71.5387577, 111.592413, 148.656262, 186.05680138, 221.02995269, 257.246767, 292.883829, 329.211723, 364.532895, 401.987176, 437.229627, 473.727684, 509.949281, 546.450908, 581.817585, 616.107437, 653.312916, 689.067753, 725.47452, 760.949746, 798.845891, 833.768784, 870.08676, 905.098953, 905.098953, 976.484269, 1014.34161, 1052.40054, 1086.30604]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(10, 6))
for i in range(4):
    plt.plot(df['t'], df[f'A{i}'], label=f'A{i}')

plt.xlabel('t')
plt.ylabel('A')
plt.title('Plot of A with respect to t')
plt.legend()
plt.grid(True)
plt.show()
