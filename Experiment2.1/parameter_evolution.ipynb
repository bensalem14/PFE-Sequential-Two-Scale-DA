# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your updated data
data = {
    't': list(range(30)),
    'A0': [3.23508959, -0.15144148, 0.03063691, 0.04138095, 0.23010393, -0.26266701, -0.16828198, 0.17261131, 0.15454535, -0.16393966, 0.07870308, -0.34084917, 0.01165558, 0.42610033, 0.04905449, 0.20402937, -0.28880762, 0.12658376, -0.27914378, 0.01544955, 0.05328293, -0.09365764, -0.40953403, -0.1622359, 0.03686776, 0.08510466, -0.03982806, 0.01792713, 0.46321974, -0.00176135],
    'A1': [3.23516662, -0.15346659, 0.02863187, 0.03945008, 0.2281452, -0.2646656, -0.17005953, 0.17070662, 0.1524983, -0.16589216, 0.07651133, -0.34256956, 0.00972669, 0.42405773, 0.0471474, 0.2020435, -0.29096077, 0.12454768, -0.28092028, 0.01362213, 0.0513313, -0.09562057, -0.41142405, -0.16440268, 0.03512258, 0.08316141, -0.04174358, 0.01589169, 0.46110494, -0.00348015],
    'A2': [-0.29508583, 0.93833446, 0.8936345, 1.12065852, 1.24050812, 0.69140173, 1.24684725, 1.17270251, 0.91885378, 0.75589025, 1.47634276, 0.74577939, 0.74702743, 1.31373037, 1.15257993, 1.47387612, 1.12091056, 1.18565669, 0.52729802, 1.03324322, 0.72515883, 1.12078368, 0.91590009, 0.7509764, 1.00675852, 1.05912907, 1.18172674, 0.95328359, 0.81759222, 0.42871962],
    'A3': [-32.98113593, 71.44432119, 111.497977, 148.561825, 185.96236478, 220.93551558, 257.152329, 292.789390, 329.117283, 364.438454, 401.892735, 437.135187, 473.633246, 509.854845, 546.356472, 581.723151, 616.013003, 653.218482, 688.973319, 725.380086, 760.855311, 798.751454, 833.674347, 870.099232, 905.004513, 942.686463, 976.389828, 1014.24717, 1052.30610, 1086.21160]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(10, 6))
for i in range(4):
    plt.plot(df['t'], df[f'A{i}'], label=f'A{i}')

plt.xlabel('t')
plt.ylabel('A')
plt.title('Plot of A with respect to t')
plt.legend()
plt.grid(True)
plt.show()
